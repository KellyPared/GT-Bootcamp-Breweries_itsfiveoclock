# %%
#8600 rows x 17 columns] breweries

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup
import time
import pprint

# %%
i = 0
url = f'https://api.openbrewerydb.org/breweries?page={i}&per_page=200'
brewery_list = []
for i in range(1,44):
    response = requests.get(url)
    brewery_data = response.json()
    brewery_list.append(brewery_data)
    time.sleep(1)

# %%
pprint.pprint(brewery_list)
# Out:
# [[{'address_2': None,
#    'address_3': None,
#    'brewery_type': 'micro',
#    'city': 'Knox',
#    'country': 'United States',
#    'county_province': None,
#    'created_at': '2023-02-21T01:41:59.300Z',
#    'id': '10-56-brewing-company-knox',
#    'latitude': '41.289715',
#    'longitude': '-86.627954',
#    'name': '10-56 Brewing Company',
#    'phone': '6308165790',
#    'postal_code': '46534',
#    'state': 'Indiana',
#    'street': '400 Brown Cir',
#    'updated_at': '2023-02-21T01:41:59.300Z',
#    'website_url': None},
#   {'address_2': None,
#    'address_3': None,
#    'brewery_type': 'large',
#    'city': 'Bend',
#    'country': 'United States',
#    'county_province': None,
#    'created_at': '2023-02-21T01:41:59.300Z',
#    'id': '10-barrel-brewing-co-bend-1',
#    'latitude': '44.08683530625218',
#    'longitude': '-121.28170597038259',
#    'name': '10 Barrel Brewing Co',
#    'phone': '5415851007',
#    'postal_code': '97701-9847',
#    'state': 'Oregon',
# ...

# %%
from itertools import chain
all_brewerys_pd = list(chain.from_iterable(brewery_list))

# %%
all_brewerys_pd
# Out:
# [{'id': '10-56-brewing-company-knox',
#   'name': '10-56 Brewing Company',
#   'brewery_type': 'micro',
#   'street': '400 Brown Cir',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Knox',
#   'state': 'Indiana',
#   'county_province': None,
#   'postal_code': '46534',
#   'country': 'United States',
#   'longitude': '-86.627954',
#   'latitude': '41.289715',
#   'phone': '6308165790',
#   'website_url': None,
#   'updated_at': '2023-02-21T01:41:59.300Z',
#   'created_at': '2023-02-21T01:41:59.300Z'},
#  {'id': '10-barrel-brewing-co-bend-1',
#   'name': '10 Barrel Brewing Co',
#   'brewery_type': 'large',
#   'street': '62970 18th St',
#   'address_2': None,
#   'address_3': None,
#   'city': 'Bend',
#   'state': 'Oregon',
#   'county_province': None,
#   'postal_code': '97701-9847',
#   'country': 'United States',
#   'longitude': '-121.28170597038259',
#   'latitude': '44.08683530625218',
#   'phone': '5415851007',
#   'website_url': 'http://www.10barrel.com',
# ...

# %%
print(len(all_brewerys_pd))
# Out:
# 8600

# %%
brewery_df = pd.DataFrame.from_records(all_brewerys_pd)
print(brewery_df)
# Out:
#                                            id  \
# 0                  10-56-brewing-company-knox
# 1                 10-barrel-brewing-co-bend-1
# 2                 10-barrel-brewing-co-bend-2
# 3          10-barrel-brewing-co-bend-pub-bend
# 4            10-barrel-brewing-co-boise-boise
# ...                                       ...
# 8595                   abigaile-hermosa-beach
# 8596               abita-brewing-co-covington
# 8597         abjuration-brewing-mc-kees-rocks
# 8598             able-baker-brewing-henderson
# 8599  able-ebenezer-brewing-company-merrimack
#
#                                  name brewery_type  \
# 0               10-56 Brewing Company        micro
# 1                10 Barrel Brewing Co        large
# 2                10 Barrel Brewing Co        large
# 3     10 Barrel Brewing Co - Bend Pub        large
# 4        10 Barrel Brewing Co - Boise        large
# ...                               ...          ...
# ...

# %%
brewery_df.describe()
# Out:
#                                 id                  name brewery_type  \
# count                         8600                  8600         8600
# unique                         200                   196            9
# top     10-56-brewing-company-knox  10 Barrel Brewing Co        micro
# freq                            43                   172         4515
#
#                street address_2 address_3     city       state  \
# count            7869       172        43     8600        8385
# unique            183         4         1      183          46
# top     400 Brown Cir  Clonmore  Dublin 2  Houston  California
# freq               43        43        43      172         903
#
#        county_province postal_code        country   longitude   latitude  \
# count              215        8600           8600        6149       6149
# unique               5         200              4         143        143
# top              Laois       46534  United States  -86.627954  41.289715
# ...

# %%
brewery_df.to_csv('brewery_list.csv')

# %%
# Create a sample dataframe with an text index
from matplotlib import pyplot as plt

plot_brewery_type = pd.DataFrame(brewery_df['brewery_type']).value_counts()
# Plot a bar chart
plot_brewery_type.plot(kind="bar")
plt.title("Types of Breweries")
# Out:
# Text(0.5, 1.0, 'Types of Breweries')

# %%
plot_brewery_state = pd.DataFrame(brewery_df['state']).value_counts()
# Plot a bar chart
plot_brewery_state.plot(kind="bar")
plt.title("States of Breweries")
# Out:
# Text(0.5, 1.0, 'States of Breweries')

# %% [markdown]
# ## Webscraping
# untapped brewery

# %%
# import module
# Out:
# b'Too Many Requests'

# %%
from bs4 import BeautifulSoup
import requests

all_breweries = []
 
# Website URL
url_untapped = 'https://untappd.com/brewery/top_rated?country=united-states&brewery_type=regional_brewery'
response = requests.get(url_untapped)

# Parse the HTML content of the page using Beautiful Soup
soup = BeautifulSoup(response.content, "html.parser")

##slide > div.cont.search-page.account-settings.ratings-page > div > div.box > div > div.beer-container.beer-list
# Find the target DOM element using its CSS selector
breweries_info = soup.select_one("#slide > div.cont.search-page.account-settings.ratings-page > div > div.box > div > div.beer-container.beer-list > div:nth-child(1)')

# Get all the siblings of the target element
siblings = breweries_info.find_next_siblings()
for row in siblings:
    dictionary = {}
    brewery_link = row.find_all(class_='href')
    if brewery_link:
        dictionary['brewery_link'] = brewery_link[0].text.strip()
    else:
        dictionary['brewery_link'] = ''

    brewery_names = row.find_all(class_='name')
    if brewery_names:
        dictionary['brewery_name'] = brewery_names[0].text.strip()
    else:
        dictionary['brewery_name'] = ''    

    brewery_location = row.find_all(class_='style')
    if brewery_location:
        dictionary['brewery_location'] = brewery_location[0].text.strip()
    else:
        dictionary['brewery_location'] = ''
    
    number_beers = row.find_all(class_='abv')
    if number_beers:
        dictionary['number_beers'] = number_beers[0].text.strip()
    else:
        dictionary['number_beers'] = ''
                                 
    brewery_ratings = row.find_all(class_='ibu')
    if brewery_ratings:
        dictionary['brewery_ratings'] = brewery_ratings[0].text.strip()
    else:
        dictionary['brewery_ratings'] = ''
                                 
    brewery_star_ratings = row.find_all(class_='caps')
    if brewery_ratings:
        dictionary['brewery_star_ratings'] = brewery_ratings[0].text.strip()
    else:
        dictionary['brewery_star_ratings'] = ''
    all_breweries.append(dictionary)
    time.sleep(5)
# Out:
#   File "/var/folders/lt/r23wrnp91wx9lpfj7gr25m3rgb08gl/T/ipykernel_7224/1163068517.py", line 15
#     breweries_info = soup.select_one("#slide > div.cont.search-page.account-settings.ratings-page > div > div.box > div > div.beer-container.beer-list > div:nth-child(1)')
#                                                                                                                                                                            ^
# SyntaxError: EOL while scanning string literal

# %%
#slide > div.cont.search-page.account-settings.ratings-page > div > div.box > div > div.beer-container.beer-list > div:nth-child(1)

# %%
#slide > div.cont.search-page.account-settings.ratings-page > div > div.box > div > div.beer-container.beer-list > div:nth-child(2)

# %%
//*[@id="slide"]/div[2]/div/div[1]/div/div[4]/div[12]

# %%
from splinter import Browser
import csv
import os
import sys
import time
os.path.dirname(sys.executable)
# Out:
# '/Users/kelly.paredes/opt/anaconda3/bin'

# %%
#browser = webdriver.Chrome()
global browser
browser = Browser('chrome')

# %%
# assign URL
url_untapped = 'https://untappd.com/brewery/top_rated?country=united-states&brewery_type=regional_brewery'
browser.visit(url_untapped)
#my_service = Service()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/lt/r23wrnp91wx9lpfj7gr25m3rgb08gl/T/ipykernel_7224/2004476494.py in <module>
#       2 url_untapped = 'https://untappd.com/brewery/top_rated?country=united-states&brewery_type=regional_brewery'
#       3 browser.visit(url_untapped)
# ----> 4 my_service = Service()
#
# NameError: name 'Service' is not defined

# %%
#//*[@id="slide"]/div[2]/div/div[1]/div/div[4]/div[1]/div[1]/p[1]/a
brewery_names = []
brewery_links = []
#//*[@id="slide"]/div[3]/div/div[1]/div/div[4]/div[1]/div[1]

breweries = browser.find_by_xpath('//*[@id="slide"]/div[3]/div/div[1]/div/div[4]')
target_href = 

for brewery in breweries:
    title_link = link.text
    brewery_links.append(title_link)
    time.sleep(1)

print(brewery_links)
<a href="/treehousebrewco">Tree House Brewing Company</a>
# Out:
# []

# %%
#//*[@id="slide"]/div[3]/div/div[1]/div/div[4]/div[1]/div[1]
